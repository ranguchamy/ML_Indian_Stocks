# %%
import yfinance as yf
import pandas as pd
from prettytable import PrettyTable
from datetime import datetime, timedelta

# Function to check if a given date is a working day
def is_working_day(date_str):
    # Parse the date string to datetime format
    date_obj = datetime.strptime(date_str, '%Y-%m-%d')

    # Check if the date falls on a weekend (Saturday or Sunday)
    if date_obj.weekday() >= 5:
        return False

    # Check if the date falls on a special working day
    special_working_days = {"2024-01-27", "2024-03-02"}  # Example: Christmas Eve
    if date_str in special_working_days:
        return True

    # Check if the date falls on a holiday
    # Add your holiday logic here
    holidays = {"2023-01-26", "2023-03-07", "2023-03-30", "2023-04-04", "2023-04-07",
                "2023-04-14", "2023-05-01", "2023-06-29", "2023-07-29", "2023-08-15",
                "2023-09-19", "2023-10-02", "2023-10-24", "2023-11-14", "2023-11-27",
                "2023-12-25","2024-01-22",
                "2024-01-26", "2024-03-08", "2024-03-25", "2024-03-29", "2024-04-11",
                "2024-04-17", "2024-05-01", "2024-06-17", "2024-07-17", "2024-08-15",
                "2024-10-02", "2024-11-01", "2024-11-15", "2024-12-25"}
    if date_str in holidays:
        return False

    # If the date is not a weekend, holiday, or special working day, it's a regular working day
    return True

# Function to get the next working date if the provided date is not a working day
def get_next_working_date(date_str):
    # Parse the date string to datetime format
    date_obj = datetime.strptime(date_str, '%Y-%m-%d')

    # Check if the date is a working day
    if is_working_day(date_str):
        return date_obj

    # If the date is not a working day, find the next working date
    while True:
        date_obj += timedelta(days=1)
        if is_working_day(date_obj.strftime('%Y-%m-%d')):
            return date_obj

# Define start and end dates
start_date = '2023-01-14'
end_date = '2024-02-24'


# Path to the Excel file
# excel_file_path = "C:/Users/91908/Documents/Raja/Share market/Analysis/Trendlyne/Data/Bajel_Increased/MCAP31122023_mylist.xlsx"

excel_file_path = "C:/Users/91908/Documents/Raja/Share market/Analysis/Trendlyne/Data/Bajel_Increased/MinimalWatchList/Azure/MCAP/2024-02-13-multigroup.xlsx"


# Read the Excel file
df = pd.read_excel(excel_file_path)


df = df[ 

                    
                (df['Market Capitalization'] > 100)&
                (df['Market Capitalization'] < 500)&

                # (df['Long Term Debt To Equity Annual'] < 1) &

                # (df['FII holding current Qtr %'] > 0)&
                (df['FII holding current Qtr %'] > 0)&
                (df['Current Price'] < 750)&



                # ((df['PE TTM Price to Earnings'] * df['EPS Annual Rs']) > (2*df['Current Price Rs']) )& - misunderstood dont use

                (df['Price to Book Value']< 2 ) &
                # (df['Price to Book Value'] < df['Industry Price to Book TTM']) &
                (df['PE TTM Price to Earnings'] > 0) & 
                (df['PE TTM Price to Earnings'] < 20) 
                # (df['EPS Qtr YoY Growth %'] < 1 )&
                # (df['PEG TTM PE to Growth'] <5 ) &

                # (df['Promoter holding pledge percentage % Qtr']< 1 ) & 
    
                
                # (df['Revenue QoQ Growth %'] > 0) &
                    # (df['Revenue Growth Qtr YoY %'] > 0) & 
                    # (df['Revenue Growth Qtr YoY %'] < 200) &
                    # (df['Total Revenue Qtr'] > df['Total Revenue 1Qtr ago']  )&
                    # (df['Total Revenue 1Qtr ago'] > df['Total Revenue 2Qtr'])
                # (df['Total Revenue 2Qtr Cr'] > df['Total Revenue 3Qtr Cr'])


                # (df['Net Cash Flow YoY Growth %'] < 1 )&

                # (df['Stock In PE Buy Zone'] < 1 )&
                # (df['Stock In PBV Buy Zone'] < 1 )&
                # (df['%Days traded below current PE Price to Earnings'] < 1 )&
                # (df['%Days traded below current Price to Book Value'] < 1 )&
                
                # (df['RSI'].notna() < 50 ) &
                # (df['% Distance from 52week high'] > 1) 

                ]
print(len(df))

# Extract stock codes from the 'Symbol' column
# stock_codes = df['Symbol'].tolist()
stock_codes = df['NSE code'].tolist()

print(stock_codes)

    # Result of (df['Price to Book Value']< 5 ) &     #             # (df['Price to Book Value'] < df['Industry Price to Book TTM']) &     #             (df['PE TTM Price to Earnings'] > 0) &     #             (df['PE TTM Price to Earnings'] < 40) & 

# Existing list of stock codes
# existing_stock_codes = ['AGI', 'ASHOKA', 'BCLIND', 'BAJAJFINSV', 'CLSEL', 'CREDITACC', 'EKC', 'FIVESTAR', 'GEOJITFSL', 'HUDCO', 'JAGRAN', 'KOPRAN', 'MMFL', 'MOREPENLAB', 'NESCO', 'OMINFRAL', 'PFS', 'PARAGMILK', 'POCL', 'RBL', 'REDINGTON', 'BASF', 'BFINVEST', 'GICRE', 'IFGLEXPOR', 'INDIAGLYCO', 'INDRAMEDCO', 'JKTYRE', 'LINCOLN', 'MASTEK', 'GREENPOWER', 'PTC', 'RUSHIL']

# ipo_stocks = ['JSFB', 'CAPITALSFB', 'MUTHOOTMF','PARKHOTELS','MEDIASSIST','FEDFINA','JIOFIN']

# Concatenate the two lists
# stock_codes = existing_stock_codes + stock_codes + ipo_stocks

stock_codes = ['DELTACORP']

# Print the combined list
print(stock_codes)


# Take the second 30 stocks -------------->>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> latest 120220242114
selected_stock_codes = stock_codes[0:130]
print(selected_stock_codes)
stock_data = {}

def calculate_rsi(data, window=14):
    delta = data.diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

for stock_code in selected_stock_codes:
    try:
        data = yf.download(stock_code+".NS", start=start_date, end=end_date)
    except Exception as e:
        print(f"Error downloading data for {stock_code}: {e}")
        continue

    if not data.empty:
        # Remove rows corresponding to holidays
        for date_str in data.index.strftime('%Y-%m-%d'):
            if not is_working_day(date_str):
                data = data[data.index != date_str]

        # Check if the DataFrame is empty after removing non-working days
        if data.empty:
            print(f"No data available for stock code: {stock_code}")
            continue

        # Calculate VWAP
        # data['Volume_Price'] = data['Volume'] * (data['High'] + data['Low'] + data['Close']) / 3
        # data['Cumulative_Volume_Price'] = data['Volume_Price'].cumsum()
        # data['Cumulative_Volume'] = data['Volume'].cumsum()
        # data['VWAP'] = data['Cumulative_Volume_Price'] / data['Cumulative_Volume']

        # Calculate average volume over the entire time range
        # average_volume = data['Volume'].mean()

        # Calculate three-day rolling average volume
        # data['Three_Day_Avg_Volume'] = data['Volume'].rolling(window=3).mean()
        
        
        data['RSI'] = calculate_rsi(data['Close'])

        # Store the data in the dictionary
        stock_data[stock_code] = data

        # # Create a PrettyTable to store the data
        # table = PrettyTable()
        # table.field_names = ["Date", "Close", "Volume", "VWAP", "Average Volume", "Three-Day Average Volume"]

        # # Add each row of data to the table
        # for index, row in data.iterrows():
        #     table.add_row([index.strftime("%Y-%m-%d"), f"{row['Close']:.2f}", f"{row['Volume']:.2f}", f"{row['VWAP']:.2f}",
        #                   f"{average_volume:.2f}", f"{row['Three_Day_Avg_Volume']:.2f}"])

        # # Print the table
        # print(f"Stock Code: {stock_code}")
        # # print(table)
        # print("\n\n")

# print(stock_data)
# Out:
# 22
# ['ALMONDZ', 'ALPA', 'AHLEAST', 'BIL', 'CORALFINAC', 'CCHHL', 'GULFPETRO', 'GENCON', 'IZMO', 'JAYSREETEA', 'JMA', 'KCPSUGIND', 'KEYFINSERV', 'KOTARISUG', 'MANAKSTEEL', 'MAWANASUG', 'MODIRUBBER', 'MUTHOOTCAP', 'NATHBIOGEN', 'PODDARMENT', 'PONNIERODE', 'RHL']
# ['DELTACORP']
# ['DELTACORP']
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\91908\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:782: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
stock_data_length = len(data)
print("Length of stock_data:", stock_data_length)
# Out:
# Length of stock_data: 126

# %%
# @title Default title text
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from prettytable import PrettyTable

# Function to create sequences for LSTM input
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Define sequence length
sequence_length = 10

# Create a PrettyTable to store the shift rows
shift_table = PrettyTable()
shift_table.field_names = ["Stock", "Date"] + list(data.columns)

# Create an empty DataFrame to store the data
datatable = pd.DataFrame(columns=["Stock", "Date"] + list(data.columns))

# Iterate over each stock's data
for stock_code, stock_data in stock_data.items():
    # Preprocessing
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(stock_data[['Close', 'Volume']].values)

    # Create sequences
    X, y = create_sequences(scaled_data, sequence_length)

    # Define and compile LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
    model.add(LSTM(units=50))
    model.add(Dense(units=2))  # Output layer with 2 neurons for Close and Volume
    model.compile(optimizer='adam', loss='mse')

    # Train LSTM model
    # model.fit(X, y, epochs=50, batch_size=32, verbose=0)
    model.fit(X, y, epochs=50, batch_size=32)

    # Predict anomalies
    predictions = model.predict(X)

    # Reshape predictions to match the shape of X
    predictions = np.repeat(predictions[:, np.newaxis, :], X.shape[1], axis=1)

    # Calculate reconstruction errors
    reconstruction_errors = np.mean(np.abs(predictions - X), axis=2)

    # Threshold for anomaly detection (e.g., 2 standard deviations from the mean)
    threshold = np.mean(reconstruction_errors) + 3 * np.std(reconstruction_errors)

    # Identify rows corresponding to shifts
    shift_rows = stock_data.iloc[sequence_length:][np.any(reconstruction_errors > threshold, axis=1)]

    # Add each row of shift_rows to the DataFrame
    for index, row in shift_rows.iterrows():
        # Create a new row with stock code, date, and row values
        new_row = pd.DataFrame([[stock_code, index.strftime("%Y-%m-%d")] + list(row)], columns=["Stock", "Date"] + list(data.columns))
        # Concatenate the new row with the existing DataFrame
        datatable = pd.concat([datatable, new_row], ignore_index=True)

# Print the DataTable
# print(datatable)

   # # Add each row of shift_rows to the PrettyTable
   #  for index, row in shift_rows.iterrows():
   #      shift_table.add_row([stock_code, index.strftime("%Y-%m-%d")] + list(row))

# Print the shift table
# print(shift_table)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 3s 11ms/step - loss: 0.0943
# Epoch 2/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0214
# Epoch 3/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0158
# Epoch 4/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0132
# Epoch 5/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0104
# Epoch 6/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0100
# Epoch 7/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0098
# Epoch 8/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0096
# Epoch 9/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0094
# Epoch 10/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0093
# Epoch 11/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0094
# Epoch 12/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0091
# Epoch 13/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0091
# Epoch 14/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0091
# Epoch 15/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0090
# Epoch 16/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0089
# Epoch 17/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0089
# Epoch 18/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0089
# Epoch 19/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0087
# Epoch 20/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0086
# Epoch 21/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0087
# Epoch 22/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0086
# Epoch 23/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0094
# Epoch 24/50
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0086
# Epoch 25/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0084
# Epoch 26/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0083
# Epoch 27/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 28/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0081
# Epoch 29/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0083
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 31/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 32/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0085
# Epoch 33/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0079
# Epoch 34/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0080
# Epoch 35/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0078
# Epoch 36/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0078
# Epoch 37/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0078
# Epoch 40/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 41/50
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0075
# Epoch 42/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0077
# Epoch 43/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0079
# Epoch 44/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0073
# Epoch 46/50
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0075
# Epoch 47/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0074
# Epoch 48/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0074
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0072
# Epoch 50/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0072
# 9/9 [==============================] - 1s 4ms/step
# C:\Users\91908\AppData\Local\Temp\ipykernel_19168\2847845939.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   datatable = pd.concat([datatable, new_row], ignore_index=True)

# %%
import sys
import datetime
from tabulate import tabulate

# Generate timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")

# Create the filename with the timestamp
log_file_path = f"message_{timestamp}.log"

old_stdout = sys.stdout

# Open the log file for writing
log_file = open(log_file_path, "w")

sys.stdout = log_file

print(tabulate(datatable, headers='keys', tablefmt='pretty', showindex=False))

sys.stdout = old_stdout

log_file.close()

print(f"Log file '{log_file_path}' with timestamp '{timestamp}' created.")
# Out:
# Log file 'message_20240224170701.log' with timestamp '20240224170701' created.

# %%
from tabulate import tabulate


print(tabulate(datatable, headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +-----------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+
# |   Stock   |    Date    |        Open        |        High        |        Low         |       Close        |     Adj Close      |   Volume   |        RSI         |
# +-----------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+
# | DELTACORP | 2023-07-13 | 187.9499969482422  | 193.35000610351562 | 178.35000610351562 | 179.5500030517578  | 179.5500030517578  | 46574904.0 | 23.386382926020772 |
# | DELTACORP | 2023-07-14 |       182.0        | 186.3000030517578  | 179.0500030517578  |       184.0        |       184.0        | 18333885.0 | 26.64941679701451  |
# | DELTACORP | 2023-07-17 | 186.60000610351562 |       187.0        | 182.39999389648438 | 183.0500030517578  | 183.0500030517578  | 6271275.0  | 24.956367310287675 |
# | DELTACORP | 2023-07-18 |       189.0        | 193.1999969482422  | 185.5500030517578  | 191.14999389648438 | 191.14999389648438 | 23578862.0 | 24.095306998063094 |
# | DELTACORP | 2023-07-19 | 188.89999389648438 | 190.8000030517578  | 186.39999389648438 | 188.35000610351562 | 188.35000610351562 | 7710589.0  |  19.9999917520025  |
# | DELTACORP | 2023-07-20 |       189.5        | 191.60000610351562 |       188.5        | 189.5500030517578  | 189.5500030517578  | 5639200.0  | 21.043155497008627 |
+------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+

# %%
from datetime import datetime, timedelta
from tabulate import tabulate


# Get the current date
current_date = datetime.now()

# Calculate the date 30 days ago
thirty_days_ago = current_date - timedelta(days=1)

# Filter datatable for records falling under the last 30 days timeframe
filtered_data = datatable[datatable['Date'] >= thirty_days_ago.strftime("%Y-%m-%d")]

# Print the filtered DataFrame
# print(filtered_data)
print(tabulate(filtered_data, headers='keys', tablefmt='pretty', showindex=False))

# %%
from datetime import datetime, timedelta
from tabulate import tabulate
import pandas as pd

# Assuming 'datatable' is your DataFrame containing the data

# Get the current date
current_date = datetime.now()

# Calculate the date 50 days ago
fifty_days_ago = current_date - timedelta(days=150)

# Filter datatable for records falling under the last 50 days timeframe
filtered_data = datatable[datatable['Date'] >= fifty_days_ago.strftime("%Y-%m-%d")]

# Convert 'Date' column to datetime
filtered_data['Date'] = pd.to_datetime(filtered_data['Date'])

# Calculate the difference between consecutive dates for each group of 'Stock'
filtered_data['Shift'] = filtered_data.groupby(['Stock'])['Date'].diff().dt.days

# Filter records where the shift is greater than 20
shift_greater_than_20 = filtered_data[filtered_data['Shift'] > 20]

# Print the datatable with the 'Shift' column added
print(tabulate(filtered_data[['Stock', 'Date', 'Shift', 'Close', 'Volume','RSI']], headers='keys', tablefmt='pretty', showindex=False))

# Print the filtered records where the shift is greater than 20
print(tabulate(shift_greater_than_20[['Stock', 'Date', 'Shift', 'Close', 'Volume','RSI']], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +------------+---------------------+-------+--------------------+-------------+--------------------+
# |   Stock    |        Date         | Shift |       Close        |   Volume    |        RSI         |
# +------------+---------------------+-------+--------------------+-------------+--------------------+
# |    AGI     | 2023-09-27 00:00:00 |  nan  | 920.9500122070312  |  289397.0   |  87.462476800607   |
# |    AGI     | 2023-09-28 00:00:00 |  1.0  | 924.9000244140625  |  145194.0   | 89.26734217861156  |
# |    AGI     | 2023-09-29 00:00:00 |  1.0  | 895.8499755859375  |  214270.0   | 80.66198196512647  |
# |    AGI     | 2023-10-03 00:00:00 |  4.0  | 911.7000122070312  |  172129.0   | 82.81937767592879  |
# |    AGI     | 2023-10-04 00:00:00 |  1.0  | 913.0999755859375  |  251931.0   | 90.10725681087919  |
# |    AGI     | 2023-10-05 00:00:00 |  1.0  | 928.7000122070312  |  745655.0   | 90.19573470913349  |
# |    AGI     | 2023-10-16 00:00:00 | 11.0  | 1023.4500122070312 |  495638.0   | 66.52823055743428  |
# |    AGI     | 2023-10-17 00:00:00 |  1.0  |       990.75       |  448278.0   | 60.11104254959284  |
# |    AGI     | 2023-10-18 00:00:00 |  1.0  | 972.0999755859375  |  296117.0   | 56.21128789274653  |
# |    AGI     | 2023-10-19 00:00:00 |  1.0  |       951.0        |  348199.0   | 53.042664269090885 |
# |    AGI     | 2023-10-20 00:00:00 |  1.0  | 970.1500244140625  |  271762.0   | 58.86635427543258  |
# |    AGI     | 2023-10-23 00:00:00 |  3.0  | 902.8499755859375  |  382003.0   | 49.05940733431216  |
# |    AGI     | 2023-10-25 00:00:00 |  2.0  | 912.1500244140625  |  379100.0   | 49.90070544810909  |
# |    AGI     | 2023-10-26 00:00:00 |  1.0  | 906.4000244140625  |  393589.0   | 47.62006564698234  |
# |    AGI     | 2023-10-27 00:00:00 |  1.0  | 898.0999755859375  |  672564.0   | 44.805832178536775 |
# |    PTC     | 2023-12-14 00:00:00 | 41.0  | 188.89999389648438 | 9948753.0  | 72.75792500206812  |
# |  AHLEAST   | 2024-01-16 00:00:00 | 82.0  | 161.0500030517578  |  74302.0   | 72.83952338288739  |
# |   CCHHL    | 2024-01-30 00:00:00 | 40.0  | 16.799999237060547 |  178421.0  | 59.43395292771707  |
# | GULFPETRO  | 2024-01-30 00:00:00 | 89.0  |  76.8499984741211  | 1791205.0  | 85.14376654152511  |
# |   GENCON   | 2024-02-08 00:00:00 | 79.0  | 60.650001525878906 |  209223.0  | 89.93575299980526  |
# | JAYSREETEA | 2023-12-26 00:00:00 | 75.0  | 110.55000305175781 |  426336.0  | 65.14287026334353  |
# | KEYFINSERV | 2024-02-13 00:00:00 | 103.0 | 182.89999389648438 |  191448.0  | 68.30679864745164  |
# | MAWANASUG  | 2024-02-08 00:00:00 | 132.0 | 105.44999694824219 |  608745.0  | 66.92605606207059  |
# | MODIRUBBER | 2024-01-16 00:00:00 | 54.0  |  92.9000015258789  |   6085.0   | 75.30123499799844  |
# | MUTHOOTCAP | 2024-01-25 00:00:00 | 92.0  |       332.25       |  165434.0  | 26.082945394333635 |
# | NATHBIOGEN | 2024-01-23 00:00:00 | 112.0 | 215.39999389648438 |  205711.0  | 53.459574799124255 |
# | PODDARMENT | 2024-01-03 00:00:00 | 43.0  | 397.1000061035156  |  28691.0   | 73.43097042380805  |
# +------------+---------------------+-------+--------------------+------------+--------------------+
# C:\Users\91908\AppData\Local\Temp\ipykernel_3940\285753425.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Date'] = pd.to_datetime(filtered_data['Date'])
# C:\Users\91908\AppData\Local\Temp\ipykernel_3940\285753425.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Shift'] = filtered_data.groupby(['Stock'])['Date'].diff().dt.days

# %%
# # Clear memory
# datatable = None
# predictions = None
# reconstruction_errors = None
# X = None
# y = None
# scaled_data = None

# %% [raw]
# datatable

# %% [raw]
# import os
# import csv
# import pandas as pd
# from datetime import datetime
#
# # Assuming 'datatable' is your data in the appropriate format
#
# # Get current date and time for file naming
# current_datetime = datetime.now().strftime("%Y%m%d%H%M%S")
#
# # Construct file path with current date and time appended to the file name
# file_path = fr'C:\Users\91908\Documents\Raja\Share market\Analysis\Trendlyne\Data\Bajel_Increased\Results\output_{current_datetime}.csv'
#
# # Check if file exists
# if not os.path.exists(file_path):
#     # If file doesn't exist, create it and write to it
#     with open(file_path, 'w', newline='') as csvfile:
#         # Assuming datatable is a DataFrame
#         if not datatable.empty:
#             datatable.to_csv(csvfile, index=False)
#             print("CSV file has been created and written successfully.")
#         else:
#             print("Datatable is empty. No data to write.")
# else:
#     # If file exists, append to it
#     with open(file_path, 'a', newline='') as csvfile:
#         # Assuming datatable is a DataFrame
#         if not datatable.empty:
#             # Check if the file is empty to determine whether to write the header
#             file_empty = os.stat(file_path).st_size == 0
#             datatable.to_csv(csvfile, mode='a', header=file_empty, index=False)
#             if file_empty:
#                 print("Header has been appended to the existing CSV file.")
#             print("Data has been appended to the existing CSV file.")
#         else:
#             print("Datatable is empty. No data to append.")
